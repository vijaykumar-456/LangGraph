# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict, Literal
from dotenv import load_dotenv
from pydantic import BaseModel, Field

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model= "models/gemini-3.1-flash-lite-preview")

# %%
class SentimentSchema(BaseModel):

    sentiment : Literal["positive", "Negative"] = Field(description = "sentiment of the review")

# %%
structured_model = model.with_structured_output(SentimentSchema, method = "function_calling" )

# %%
prompt = " what is the sentiment of the following review - The software is not bad "
structured_model.invoke(prompt).sentiment
# Out:
# 'positive'
